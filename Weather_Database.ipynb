# %% [markdown]
# ## Challenge Part 1 get the weather description and amount of precipitation for each city

# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitudes and longitudes combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 1500)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 1500)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []

# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique then add it to the cities list
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 616

# %%
# Import the request library
import requests

from datetime import datetime

from config import weather_api_key

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# List of city data
city_data = []
# Print to logger
print("Beginning Data Retrieval")
print("-" * 25)

# Create a counter
record_count = 1
set_count = 1
for index, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purpose
    if(index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city
    city_url = f'{url}&q={city.replace(" ", "+")}'
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0
            
        # Append the city information into city_data
        city_data.append(
        {
            "City": city.title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Current Description": city_weather_description,
            "Rain (inches)": city_rain_inches,
            "Snow (inches)": city_snow_inches,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country
        })
    except:
        print("City not found. Skipping...")
        pass
# Indicate that the Data Loading is complete
print("-" * 20)
print("Data Retrieval Complete")
print("-" * 20)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | aitape
# Processing Record 3 of Set 1 | almonte
# Processing Record 4 of Set 1 | codrington
# Processing Record 5 of Set 1 | san patricio
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | inhambane
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | shar
# Processing Record 10 of Set 1 | tambura
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | belfast
# Processing Record 13 of Set 1 | santo antonio do amparo
# Processing Record 14 of Set 1 | gobabis
# Processing Record 15 of Set 1 | kavieng
# City not found. Skipping...
# Processing Record 16 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 1 | tual
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | kahului
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | lompoc
# Processing Record 24 of Set 1 | rehoboth
# Processing Record 25 of Set 1 | dhola
# Processing Record 26 of Set 1 | vao
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | boa vista
# Processing Record 30 of Set 1 | praia da vitoria
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | sawtell
# Processing Record 33 of Set 1 | iqaluit
# Processing Record 34 of Set 1 | tarata
# Processing Record 35 of Set 1 | sorland
# Processing Record 36 of Set 1 | khatanga
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | nikolskoye
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | negombo
# Processing Record 41 of Set 1 | bengkulu
# Processing Record 42 of Set 1 | babanusah
# City not found. Skipping...
# Processing Record 43 of Set 1 | yar-sale
# Processing Record 44 of Set 1 | yining
# Processing Record 45 of Set 1 | carnarvon
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | rovaniemi
# Processing Record 50 of Set 1 | lata
# Processing Record 1 of Set 2 | santa cruz
# Processing Record 2 of Set 2 | fairbanks
# Processing Record 3 of Set 2 | igrim
# Processing Record 4 of Set 2 | mahebourg
# Processing Record 5 of Set 2 | muros
# Processing Record 6 of Set 2 | buraydah
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | iquitos
# Processing Record 9 of Set 2 | svetlogorsk
# Processing Record 10 of Set 2 | kerman
# Processing Record 11 of Set 2 | haines junction
# Processing Record 12 of Set 2 | cherskiy
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | dien bien
# City not found. Skipping...
# Processing Record 15 of Set 2 | esso
# Processing Record 16 of Set 2 | peruibe
# Processing Record 17 of Set 2 | salina
# Processing Record 18 of Set 2 | kita
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | viransehir
# Processing Record 21 of Set 2 | chokurdakh
# Processing Record 22 of Set 2 | guerrero negro
# Processing Record 23 of Set 2 | norman wells
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | college
# Processing Record 26 of Set 2 | saint george
# Processing Record 27 of Set 2 | prince rupert
# Processing Record 28 of Set 2 | olafsvik
# Processing Record 29 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 2 | ushtobe
# Processing Record 31 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 2 | barrow
# Processing Record 33 of Set 2 | agirish
# Processing Record 34 of Set 2 | hobart
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | mocajuba
# Processing Record 37 of Set 2 | acapulco
# Processing Record 38 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 2 | shache
# Processing Record 40 of Set 2 | port macquarie
# Processing Record 41 of Set 2 | akyab
# Processing Record 42 of Set 2 | laiyang
# Processing Record 43 of Set 2 | kaitangata
# Processing Record 44 of Set 2 | trinidad
# Processing Record 45 of Set 2 | vavozh
# Processing Record 46 of Set 2 | meulaboh
# Processing Record 47 of Set 2 | lebu
# Processing Record 48 of Set 2 | bhainsdehi
# Processing Record 49 of Set 2 | new norfolk
# Processing Record 50 of Set 2 | mehamn
# Processing Record 1 of Set 3 | bluff
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | bredasdorp
# Processing Record 5 of Set 3 | yozgat
# Processing Record 6 of Set 3 | sikandra
# Processing Record 7 of Set 3 | fort-shevchenko
# Processing Record 8 of Set 3 | port alfred
# Processing Record 9 of Set 3 | beyneu
# Processing Record 10 of Set 3 | wanning
# Processing Record 11 of Set 3 | kodiak
# Processing Record 12 of Set 3 | sahrak
# City not found. Skipping...
# Processing Record 13 of Set 3 | kawalu
# Processing Record 14 of Set 3 | namibe
# Processing Record 15 of Set 3 | alamosa
# Processing Record 16 of Set 3 | teya
# Processing Record 17 of Set 3 | belgrade
# Processing Record 18 of Set 3 | taos
# Processing Record 19 of Set 3 | viedma
# Processing Record 20 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 3 | tiksi
# Processing Record 22 of Set 3 | haverfordwest
# Processing Record 23 of Set 3 | tiznit
# Processing Record 24 of Set 3 | ambulu
# Processing Record 25 of Set 3 | turukhansk
# Processing Record 26 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 3 | magistralnyy
# Processing Record 28 of Set 3 | bismarck
# Processing Record 29 of Set 3 | vaini
# Processing Record 30 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 3 | severo-kurilsk
# Processing Record 32 of Set 3 | yellowknife
# Processing Record 33 of Set 3 | victoria
# Processing Record 34 of Set 3 | kavaratti
# Processing Record 35 of Set 3 | kloulklubed
# Processing Record 36 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 37 of Set 3 | lavrentiya
# Processing Record 38 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 3 | saldanha
# Processing Record 41 of Set 3 | bagdarin
# Processing Record 42 of Set 3 | domingo arenas
# Processing Record 43 of Set 3 | innisfail
# Processing Record 44 of Set 3 | henzada
# City not found. Skipping...
# Processing Record 45 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 3 | atuona
# Processing Record 47 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 49 of Set 3 | namatanai
# Processing Record 50 of Set 3 | arandis
# Processing Record 1 of Set 4 | blackwater
# Processing Record 2 of Set 4 | san isidro
# Processing Record 3 of Set 4 | maple creek
# Processing Record 4 of Set 4 | union
# Processing Record 5 of Set 4 | jalu
# Processing Record 6 of Set 4 | upernavik
# Processing Record 7 of Set 4 | lannion
# Processing Record 8 of Set 4 | cabo san lucas
# Processing Record 9 of Set 4 | tasiilaq
# Processing Record 10 of Set 4 | palomares
# Processing Record 11 of Set 4 | ugoofaaru
# Processing Record 12 of Set 4 | laguna
# Processing Record 13 of Set 4 | alofi
# Processing Record 14 of Set 4 | arraial do cabo
# Processing Record 15 of Set 4 | coquimbo
# Processing Record 16 of Set 4 | dingle
# Processing Record 17 of Set 4 | nieuw amsterdam
# Processing Record 18 of Set 4 | beringovskiy
# Processing Record 19 of Set 4 | esperance
# Processing Record 20 of Set 4 | vila velha
# Processing Record 21 of Set 4 | salalah
# Processing Record 22 of Set 4 | nanortalik
# Processing Record 23 of Set 4 | calabozo
# Processing Record 24 of Set 4 | geraldton
# Processing Record 25 of Set 4 | grand gaube
# Processing Record 26 of Set 4 | nome
# Processing Record 27 of Set 4 | pisco
# Processing Record 28 of Set 4 | gualan
# Processing Record 29 of Set 4 | umm durman
# City not found. Skipping...
# Processing Record 30 of Set 4 | dawei
# Processing Record 31 of Set 4 | quelimane
# Processing Record 32 of Set 4 | castro
# Processing Record 33 of Set 4 | nevers
# Processing Record 34 of Set 4 | banda aceh
# Processing Record 35 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 4 | burnie
# Processing Record 38 of Set 4 | tak
# Processing Record 39 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 4 | shelburne
# Processing Record 41 of Set 4 | gladstone
# Processing Record 42 of Set 4 | longyearbyen
# Processing Record 43 of Set 4 | crotone
# Processing Record 44 of Set 4 | mombaca
# Processing Record 45 of Set 4 | malkapur
# Processing Record 46 of Set 4 | katherine
# Processing Record 47 of Set 4 | itarema
# Processing Record 48 of Set 4 | hambantota
# Processing Record 49 of Set 4 | mandurah
# Processing Record 50 of Set 4 | am timan
# Processing Record 1 of Set 5 | imbituba
# Processing Record 2 of Set 5 | sanmenxia
# Processing Record 3 of Set 5 | hithadhoo
# Processing Record 4 of Set 5 | veraval
# Processing Record 5 of Set 5 | lalmohan
# Processing Record 6 of Set 5 | katsuura
# Processing Record 7 of Set 5 | avarua
# Processing Record 8 of Set 5 | fukue
# Processing Record 9 of Set 5 | port elizabeth
# Processing Record 10 of Set 5 | mayna
# Processing Record 11 of Set 5 | avera
# Processing Record 12 of Set 5 | kambove
# Processing Record 13 of Set 5 | antofagasta
# Processing Record 14 of Set 5 | kyabe
# Processing Record 15 of Set 5 | srandakan
# Processing Record 16 of Set 5 | sindor
# Processing Record 17 of Set 5 | rudnyy
# Processing Record 18 of Set 5 | martapura
# Processing Record 19 of Set 5 | ust-maya
# Processing Record 20 of Set 5 | sigli
# Processing Record 21 of Set 5 | limot
# Processing Record 22 of Set 5 | ilulissat
# Processing Record 23 of Set 5 | port hedland
# Processing Record 24 of Set 5 | cayenne
# Processing Record 25 of Set 5 | los llanos de aridane
# Processing Record 26 of Set 5 | ferrol
# Processing Record 27 of Set 5 | timizart
# Processing Record 28 of Set 5 | strelka
# Processing Record 29 of Set 5 | santa lucia
# Processing Record 30 of Set 5 | luorong
# Processing Record 31 of Set 5 | rosario do sul
# Processing Record 32 of Set 5 | kieta
# Processing Record 33 of Set 5 | odessa
# Processing Record 34 of Set 5 | kenai
# Processing Record 35 of Set 5 | kingman
# Processing Record 36 of Set 5 | skhisma
# Processing Record 37 of Set 5 | abha
# Processing Record 38 of Set 5 | kayes
# Processing Record 39 of Set 5 | vanimo
# Processing Record 40 of Set 5 | ginir
# Processing Record 41 of Set 5 | salinopolis
# Processing Record 42 of Set 5 | jamestown
# Processing Record 43 of Set 5 | ostrovnoy
# Processing Record 44 of Set 5 | talnakh
# Processing Record 45 of Set 5 | maceio
# Processing Record 46 of Set 5 | mount gambier
# Processing Record 47 of Set 5 | santiago del estero
# Processing Record 48 of Set 5 | ilo
# Processing Record 49 of Set 5 | arti
# Processing Record 50 of Set 5 | caravelas
# Processing Record 1 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 6 | skarnes
# Processing Record 3 of Set 6 | port blair
# Processing Record 4 of Set 6 | boyolangu
# Processing Record 5 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 6 of Set 6 | niksic
# Processing Record 7 of Set 6 | port keats
# Processing Record 8 of Set 6 | constitucion
# Processing Record 9 of Set 6 | kasongo-lunda
# Processing Record 10 of Set 6 | yinchuan
# Processing Record 11 of Set 6 | chimbote
# Processing Record 12 of Set 6 | melekhovskaya
# City not found. Skipping...
# Processing Record 13 of Set 6 | samarai
# Processing Record 14 of Set 6 | kant
# Processing Record 15 of Set 6 | khiri mat
# Processing Record 16 of Set 6 | zyryanovsk
# Processing Record 17 of Set 6 | cidreira
# Processing Record 18 of Set 6 | sao filipe
# Processing Record 19 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 6 | douentza
# Processing Record 21 of Set 6 | pokhara
# Processing Record 22 of Set 6 | hirara
# Processing Record 23 of Set 6 | chuy
# Processing Record 24 of Set 6 | kautokeino
# Processing Record 25 of Set 6 | clyde river
# Processing Record 26 of Set 6 | callaway
# Processing Record 27 of Set 6 | usogorsk
# Processing Record 28 of Set 6 | kupang
# Processing Record 29 of Set 6 | klaksvik
# Processing Record 30 of Set 6 | aklavik
# Processing Record 31 of Set 6 | cap-aux-meules
# Processing Record 32 of Set 6 | carlagan
# Processing Record 33 of Set 6 | nouadhibou
# Processing Record 34 of Set 6 | pundaguitan
# Processing Record 35 of Set 6 | ahipara
# Processing Record 36 of Set 6 | biggar
# Processing Record 37 of Set 6 | saint-philippe
# Processing Record 38 of Set 6 | chililabombwe
# Processing Record 39 of Set 6 | palmer
# Processing Record 40 of Set 6 | palembang
# Processing Record 41 of Set 6 | bollnas
# Processing Record 42 of Set 6 | auki
# Processing Record 43 of Set 6 | bethel
# Processing Record 44 of Set 6 | vila franca do campo
# Processing Record 45 of Set 6 | provideniya
# Processing Record 46 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 47 of Set 6 | ginda
# Processing Record 48 of Set 6 | sao joao da barra
# Processing Record 49 of Set 6 | forbes
# Processing Record 50 of Set 6 | karasjok
# Processing Record 1 of Set 7 | saint anthony
# Processing Record 2 of Set 7 | sitka
# Processing Record 3 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 4 of Set 7 | kindu
# Processing Record 5 of Set 7 | khanpur
# Processing Record 6 of Set 7 | kungalv
# Processing Record 7 of Set 7 | severnyy-kospashskiy
# Processing Record 8 of Set 7 | pamyat parizhskoy kommuny
# Processing Record 9 of Set 7 | sulangan
# Processing Record 10 of Set 7 | omagari
# Processing Record 11 of Set 7 | mariental
# Processing Record 12 of Set 7 | pangnirtung
# Processing Record 13 of Set 7 | samarinda
# Processing Record 14 of Set 7 | revda
# Processing Record 15 of Set 7 | gualaquiza
# Processing Record 16 of Set 7 | george
# Processing Record 17 of Set 7 | ati
# Processing Record 18 of Set 7 | mananjary
# Processing Record 19 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 20 of Set 7 | platteville
# Processing Record 21 of Set 7 | lewistown
# Processing Record 22 of Set 7 | bambous virieux
# Processing Record 23 of Set 7 | las palmas
# Processing Record 24 of Set 7 | caconda
# Processing Record 25 of Set 7 | langres
# Processing Record 26 of Set 7 | noumea
# Processing Record 27 of Set 7 | mackay
# Processing Record 28 of Set 7 | hay river
# Processing Record 29 of Set 7 | nikel
# Processing Record 30 of Set 7 | freeport
# Processing Record 31 of Set 7 | luwuk
# Processing Record 32 of Set 7 | tazovskiy
# Processing Record 33 of Set 7 | altagracia de orituco
# Processing Record 34 of Set 7 | mitsamiouli
# Processing Record 35 of Set 7 | beisfjord
# Processing Record 36 of Set 7 | gizo
# Processing Record 37 of Set 7 | marzuq
# Processing Record 38 of Set 7 | reggio di calabria
# Processing Record 39 of Set 7 | tabou
# Processing Record 40 of Set 7 | lahij
# Processing Record 41 of Set 7 | jinchang
# Processing Record 42 of Set 7 | sibolga
# Processing Record 43 of Set 7 | te anau
# Processing Record 44 of Set 7 | port hawkesbury
# Processing Record 45 of Set 7 | buin
# Processing Record 46 of Set 7 | contepec
# Processing Record 47 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 7 | portland
# Processing Record 49 of Set 7 | andenes
# Processing Record 50 of Set 7 | hovd
# Processing Record 1 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 2 of Set 8 | zapolyarnyy
# Processing Record 3 of Set 8 | churapcha
# Processing Record 4 of Set 8 | palmas
# Processing Record 5 of Set 8 | karmala
# Processing Record 6 of Set 8 | opava
# Processing Record 7 of Set 8 | baixo guandu
# Processing Record 8 of Set 8 | bara
# Processing Record 9 of Set 8 | ahtopol
# Processing Record 10 of Set 8 | ardakan
# Processing Record 11 of Set 8 | korla
# Processing Record 12 of Set 8 | narsaq
# Processing Record 13 of Set 8 | ayan
# Processing Record 14 of Set 8 | torbay
# Processing Record 15 of Set 8 | rundu
# Processing Record 16 of Set 8 | koindu
# Processing Record 17 of Set 8 | varhaug
# Processing Record 18 of Set 8 | rafai
# Processing Record 19 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 20 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 21 of Set 8 | yaan
# Processing Record 22 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 23 of Set 8 | pacific grove
# Processing Record 24 of Set 8 | bhadra
# Processing Record 25 of Set 8 | uuemoisa
# Processing Record 26 of Set 8 | diapaga
# Processing Record 27 of Set 8 | santa fe
# Processing Record 28 of Set 8 | ubaitaba
# Processing Record 29 of Set 8 | mareeba
# Processing Record 30 of Set 8 | fort nelson
# Processing Record 31 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 8 | merauke
# Processing Record 33 of Set 8 | rawson
# Processing Record 34 of Set 8 | sembakung
# Processing Record 35 of Set 8 | sao gabriel da cachoeira
# Processing Record 36 of Set 8 | inverell
# Processing Record 37 of Set 8 | kalmunai
# Processing Record 38 of Set 8 | nangong
# Processing Record 39 of Set 8 | gao
# Processing Record 40 of Set 8 | west bay
# Processing Record 41 of Set 8 | luderitz
# Processing Record 42 of Set 8 | kaka
# Processing Record 43 of Set 8 | leopold
# Processing Record 44 of Set 8 | nemuro
# Processing Record 45 of Set 8 | loa janan
# Processing Record 46 of Set 8 | maiduguri
# Processing Record 47 of Set 8 | saint-louis
# Processing Record 48 of Set 8 | isangel
# Processing Record 49 of Set 8 | warragul
# Processing Record 50 of Set 8 | airai
# Processing Record 1 of Set 9 | husavik
# Processing Record 2 of Set 9 | zhigansk
# Processing Record 3 of Set 9 | voh
# Processing Record 4 of Set 9 | hofn
# Processing Record 5 of Set 9 | kiruna
# Processing Record 6 of Set 9 | puerto ayacucho
# Processing Record 7 of Set 9 | camalu
# Processing Record 8 of Set 9 | demirci
# Processing Record 9 of Set 9 | songjianghe
# Processing Record 10 of Set 9 | saint-francois
# Processing Record 11 of Set 9 | ust-kut
# Processing Record 12 of Set 9 | minsk
# Processing Record 13 of Set 9 | nenjiang
# Processing Record 14 of Set 9 | tsienyane
# City not found. Skipping...
# Processing Record 15 of Set 9 | santa rosa
# Processing Record 16 of Set 9 | boa esperanca
# Processing Record 17 of Set 9 | darhan
# Processing Record 18 of Set 9 | el tigre
# Processing Record 19 of Set 9 | burica
# City not found. Skipping...
# Processing Record 20 of Set 9 | grindavik
# Processing Record 21 of Set 9 | bathsheba
# Processing Record 22 of Set 9 | kingsville
# Processing Record 23 of Set 9 | tokur
# Processing Record 24 of Set 9 | kirakira
# Processing Record 25 of Set 9 | ibipeba
# Processing Record 26 of Set 9 | taoudenni
# Processing Record 27 of Set 9 | puerto colombia
# Processing Record 28 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 9 | nishihara
# Processing Record 30 of Set 9 | progreso
# Processing Record 31 of Set 9 | waingapu
# Processing Record 32 of Set 9 | chaibasa
# Processing Record 33 of Set 9 | pevek
# Processing Record 34 of Set 9 | lagoa
# Processing Record 35 of Set 9 | emba
# Processing Record 36 of Set 9 | vestbygda
# City not found. Skipping...
# Processing Record 37 of Set 9 | balakhninskiy
# Processing Record 38 of Set 9 | sakata
# Processing Record 39 of Set 9 | okhotsk
# Processing Record 40 of Set 9 | gaffney
# Processing Record 41 of Set 9 | omboue
# Processing Record 42 of Set 9 | kitimat
# Processing Record 43 of Set 9 | ayotzintepec
# Processing Record 44 of Set 9 | sabang
# Processing Record 45 of Set 9 | malanje
# Processing Record 46 of Set 9 | ileza
# Processing Record 47 of Set 9 | hasaki
# Processing Record 48 of Set 9 | peniche
# Processing Record 49 of Set 9 | barra do garcas
# Processing Record 50 of Set 9 | vostok
# Processing Record 1 of Set 10 | jacqueville
# Processing Record 2 of Set 10 | broome
# Processing Record 3 of Set 10 | denpasar
# Processing Record 4 of Set 10 | xuddur
# Processing Record 5 of Set 10 | yumen
# Processing Record 6 of Set 10 | presidencia roque saenz pena
# Processing Record 7 of Set 10 | kempele
# Processing Record 8 of Set 10 | ayia galini
# Processing Record 9 of Set 10 | berlevag
# Processing Record 10 of Set 10 | nogliki
# Processing Record 11 of Set 10 | coahuayana
# Processing Record 12 of Set 10 | ovre ardal
# Processing Record 13 of Set 10 | stornoway
# Processing Record 14 of Set 10 | vardo
# Processing Record 15 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 10 | sangar
# Processing Record 17 of Set 10 | limbang
# Processing Record 18 of Set 10 | tura
# Processing Record 19 of Set 10 | victoria point
# Processing Record 20 of Set 10 | cuamba
# Processing Record 21 of Set 10 | san carlos
# Processing Record 22 of Set 10 | cacule
# Processing Record 23 of Set 10 | kargasok
# Processing Record 24 of Set 10 | port lincoln
# Processing Record 25 of Set 10 | nouakchott
# Processing Record 26 of Set 10 | washington
# Processing Record 27 of Set 10 | flin flon
# Processing Record 28 of Set 10 | harboore
# Processing Record 29 of Set 10 | nueve de julio
# Processing Record 30 of Set 10 | qaqortoq
# Processing Record 31 of Set 10 | romodanovo
# Processing Record 32 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 33 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 34 of Set 10 | birjand
# Processing Record 35 of Set 10 | coruripe
# Processing Record 36 of Set 10 | fontem
# Processing Record 37 of Set 10 | san rafael
# Processing Record 38 of Set 10 | trat
# Processing Record 39 of Set 10 | srebrenik
# Processing Record 40 of Set 10 | chapais
# Processing Record 41 of Set 10 | ponta do sol
# Processing Record 42 of Set 10 | filadelfia
# Processing Record 43 of Set 10 | valkeakoski
# Processing Record 44 of Set 10 | lodja
# Processing Record 45 of Set 10 | de aar
# Processing Record 46 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 47 of Set 10 | rio gallegos
# Processing Record 48 of Set 10 | lufkin
# Processing Record 49 of Set 10 | koslan
# Processing Record 50 of Set 10 | santona
# Processing Record 1 of Set 11 | labuhan
# Processing Record 2 of Set 11 | isabela
# Processing Record 3 of Set 11 | nara
# Processing Record 4 of Set 11 | tres arroyos
# Processing Record 5 of Set 11 | nabire
# Processing Record 6 of Set 11 | tigil
# Processing Record 7 of Set 11 | zarcero
# Processing Record 8 of Set 11 | salym
# Processing Record 9 of Set 11 | chicama
# Processing Record 10 of Set 11 | daru
# Processing Record 11 of Set 11 | warmbad
# Processing Record 12 of Set 11 | cap malheureux
# Processing Record 13 of Set 11 | broken hill
# Processing Record 14 of Set 11 | atar
# Processing Record 15 of Set 11 | mansa
# Processing Record 16 of Set 11 | sansai
# City not found. Skipping...
# Processing Record 17 of Set 11 | bandarbeyla
# Processing Record 18 of Set 11 | krasnoselkup
# Processing Record 19 of Set 11 | ningxiang
# Processing Record 20 of Set 11 | tessalit
# Processing Record 21 of Set 11 | hammerfest
# Processing Record 22 of Set 11 | aksu
# Processing Record 23 of Set 11 | juneau
# Processing Record 24 of Set 11 | puerto escondido
# Processing Record 25 of Set 11 | ekibastuz
# Processing Record 26 of Set 11 | shagonar
# Processing Record 27 of Set 11 | deputatskiy
# Processing Record 28 of Set 11 | clonakilty
# Processing Record 29 of Set 11 | lola
# Processing Record 30 of Set 11 | helong
# Processing Record 31 of Set 11 | santa vitoria do palmar
# Processing Record 32 of Set 11 | sobolevo
# Processing Record 33 of Set 11 | chernitsyno
# Processing Record 34 of Set 11 | ponnani
# Processing Record 35 of Set 11 | fortuna
# Processing Record 36 of Set 11 | ahuimanu
# Processing Record 37 of Set 11 | faanui
# Processing Record 38 of Set 11 | sioux lookout
# Processing Record 39 of Set 11 | puerto del rosario
# Processing Record 40 of Set 11 | damghan
# Processing Record 41 of Set 11 | gurskoye
# City not found. Skipping...
# Processing Record 42 of Set 11 | ust-omchug
# Processing Record 43 of Set 11 | souillac
# Processing Record 44 of Set 11 | ikongo
# Processing Record 45 of Set 11 | riviere-au-renard
# Processing Record 46 of Set 11 | buala
# Processing Record 47 of Set 11 | ozu
# Processing Record 48 of Set 11 | bilibino
# Processing Record 49 of Set 11 | port moresby
# Processing Record 50 of Set 11 | charters towers
# Processing Record 1 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 2 of Set 12 | savannah bight
# Processing Record 3 of Set 12 | tuatapere
# Processing Record 4 of Set 12 | richards bay
# Processing Record 5 of Set 12 | yulara
# Processing Record 6 of Set 12 | usinsk
# Processing Record 7 of Set 12 | pakxe
# Processing Record 8 of Set 12 | marawi
# Processing Record 9 of Set 12 | kanbe
# Processing Record 10 of Set 12 | san quintin
# Processing Record 11 of Set 12 | hanmer springs
# Processing Record 12 of Set 12 | ewa beach
# Processing Record 13 of Set 12 | andros town
# Processing Record 14 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 15 of Set 12 | bilma
# Processing Record 16 of Set 12 | porosozero
# Processing Record 17 of Set 12 | banmo
# City not found. Skipping...
# Processing Record 18 of Set 12 | puerto baquerizo moreno
# Processing Record 19 of Set 12 | belaya gora
# Processing Record 20 of Set 12 | ellenabad
# Processing Record 21 of Set 12 | la rioja
# Processing Record 22 of Set 12 | cherkasskoye
# Processing Record 23 of Set 12 | sergeyevka
# Processing Record 24 of Set 12 | along
# Processing Record 25 of Set 12 | henties bay
# Processing Record 26 of Set 12 | creston
# Processing Record 27 of Set 12 | florida
# Processing Record 28 of Set 12 | goderich
# Processing Record 29 of Set 12 | moose factory
# Processing Record 30 of Set 12 | altamira
# Processing Record 31 of Set 12 | dongsheng
# Processing Record 32 of Set 12 | hamilton
# Processing Record 33 of Set 12 | plettenberg bay
# Processing Record 34 of Set 12 | brewster
# Processing Record 35 of Set 12 | tecoanapa
# Processing Record 36 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 12 | privokzalnyy
# City not found. Skipping...
# Processing Record 38 of Set 12 | vrangel
# Processing Record 39 of Set 12 | manokwari
# Processing Record 40 of Set 12 | mandalgovi
# Processing Record 41 of Set 12 | alpena
# Processing Record 42 of Set 12 | lethem
# Processing Record 43 of Set 12 | sanary-sur-mer
# Processing Record 44 of Set 12 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 45 of Set 12 | roald
# Processing Record 46 of Set 12 | skjervoy
# Processing Record 47 of Set 12 | kearney
# Processing Record 48 of Set 12 | bud
# Processing Record 49 of Set 12 | roebourne
# Processing Record 50 of Set 12 | egvekinot
# Processing Record 1 of Set 13 | lima
# Processing Record 2 of Set 13 | vestmannaeyjar
# Processing Record 3 of Set 13 | rio grande
# Processing Record 4 of Set 13 | miri
# Processing Record 5 of Set 13 | paita
# Processing Record 6 of Set 13 | arman
# Processing Record 7 of Set 13 | harper
# Processing Record 8 of Set 13 | sao miguel do araguaia
# Processing Record 9 of Set 13 | sao jose da coroa grande
# Processing Record 10 of Set 13 | fare
# Processing Record 11 of Set 13 | adeje
# Processing Record 12 of Set 13 | sistranda
# Processing Record 13 of Set 13 | maxixe
# Processing Record 14 of Set 13 | margate
# Processing Record 15 of Set 13 | leona vicario
# Processing Record 16 of Set 13 | khandbari
# --------------------
# Data Retrieval Complete
# --------------------

# %%
len(city_data)
# Out:
# 563

# %%
# convert list of dictionaries to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp Current Description  Rain (inches)  \
# 0       Mataura -46.19  168.86     39.00           clear sky           0.00
# 1        Aitape  -3.14  142.35     83.70          light rain           0.71
# 2       Almonte  37.26   -6.52     72.00           clear sky           0.00
# 3    Codrington -38.27  141.97     54.27          light rain           0.27
# 4  San Patricio  19.22 -104.70     80.80          few clouds           0.00
# 5  Punta Arenas -53.15  -70.92     37.40     overcast clouds           0.00
# 6     Inhambane -23.86   35.38     55.40                mist           0.00
# 7       Rikitea -23.12 -134.97     70.34       broken clouds           0.00
# 8          Shar  49.59   81.05     69.44           clear sky           0.00
# 9       Tambura   5.60   27.47     72.36     overcast clouds           0.00
#
#    Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0              0        83           0        3.00      NZ
# 1              0        78          60        6.44      PG
# 2              0        58           0        6.15      ES
# 3              0        80          70       21.63      AU
# 4              0        69          16        2.98      MX
# 5              0        93          98        5.82      CL
# 6              0        93          20        6.62      MZ
# 7              0        67          73       17.60      PF
# 8              0        24           0        3.29      KZ
# 9              0        91          99        1.41      SS

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description',
#        'Rain (inches)', 'Snow (inches)', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country'],
#       dtype='object')

# %%
new_column_order = sorted(city_data_df.columns.tolist())
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City  Cloudiness Country Current Description  Humidity    Lat  \
# 0          Mataura           0      NZ           clear sky        83 -46.19
# 1           Aitape          60      PG          light rain        78  -3.14
# 2          Almonte           0      ES           clear sky        58  37.26
# 3       Codrington          70      AU          light rain        80 -38.27
# 4     San Patricio          16      MX          few clouds        69  19.22
# ..             ...         ...     ...                 ...       ...    ...
# 558      Sistranda          75      NO       broken clouds        87  63.73
# 559         Maxixe          20      MZ                mist        93 -23.86
# 560        Margate          10      GB           clear sky        72  51.38
# 561  Leona Vicario          20      MX          few clouds        83  20.97
# 562      Khandbari          71      NP          light rain        55  27.37
#
#         Lng  Max Temp  Rain (inches)  Snow (inches)  Wind Speed
# 0    168.86     39.00           0.00              0        3.00
# 1    142.35     83.70           0.71              0        6.44
# 2     -6.52     72.00           0.00              0        6.15
# 3    141.97     54.27           0.27              0       21.63
# 4   -104.70     80.80           0.00              0        2.98
# ..      ...       ...            ...            ...         ...
# 558    8.83     60.80           0.00              0        4.70
# 559   35.35     55.40           0.00              0        6.13
# 560    1.39     60.01           0.00              0        1.99
# 561  -87.19     82.40           0.00              0        6.93
# 562   87.20     86.14           0.42              0        4.81
#
# [563 rows x 11 columns]

# %%
raining_cities = city_data_df.loc[city_data_df["Rain (inches)"] > 0]
raining_cities.head()
# Out:
#           City  Cloudiness Country Current Description  Humidity    Lat  \
# 1       Aitape          60      PG          light rain        78  -3.14
# 3   Codrington          70      AU          light rain        80 -38.27
# 16   Busselton          99      AU       moderate rain        33 -33.65
# 32       Kapaa          90      US          light rain        83  22.08
# 36    Bengkulu          79      ID          light rain        69  -3.80
#
#        Lng  Max Temp  Rain (inches)  Snow (inches)  Wind Speed
# 1   142.35     83.70           0.71              0        6.44
# 3   141.97     54.27           0.27              0       21.63
# 16  115.33     66.00           1.90              0       25.50
# 32 -159.32     75.99           0.51              0        5.82
# 36  102.27     84.63           0.19              0        8.21

# %%
snowing_cities = city_data_df.loc[city_data_df["Snow (inches)"] > 0]
snowing_cities.head()
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Current Description, Humidity, Lat, Lng, Max Temp, Rain (inches), Snow (inches), Wind Speed]
# Index: []

# %%
# Create the output file (CSV)
output_data_file = "data/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label = "City_ID")
